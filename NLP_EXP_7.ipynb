# %% [markdown]
# <a href="https://colab.research.google.com/github/huzaifamulla/UIN-231A017-_-NLP-EXPERIMENTS/blob/main/NLP_EXP_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mulla Huzaifa Sufyan - 231A017
import nltk
# Download the necessary resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
#Mulla Huzaifa Sufyan - 231A017
text="""U.S. Recognition of Indian Independence, 1947.
The United States recognized the Union of India as an independent state on August 15, 1947, when President Harry S. Truman sent a congratulatory message to Lord Louis Mountbatten, Governor General of the Dominion of India. It was on this date that, in accordance with the British Parliament’s India Independence Act of July 18, 1947, the Union of India and Pakistan were created from the former “British India” that had been a part of the British Empire.
The formal process that led to Indian independence began with a report that the British government issued on May 16, 1946, which recommended the formation of an interim government in India to devise a constitution as part of a process by which India would achieve independence from Great Britain. An Interim Government of India was formed on September 2, 1946, and this is the government with which the United States established diplomatic relations prior to formal Indian independence (see Diplomatic Relations below)."""
print(text)
# Out:
# U.S. Recognition of Indian Independence, 1947.
# The United States recognized the Union of India as an independent state on August 15, 1947, when President Harry S. Truman sent a congratulatory message to Lord Louis Mountbatten, Governor General of the Dominion of India. It was on this date that, in accordance with the British Parliament’s India Independence Act of July 18, 1947, the Union of India and Pakistan were created from the former “British India” that had been a part of the British Empire.
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
import nltk
nltk.download('punkt_tab')
tokens=word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
tagged_tokens=pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('U.S', 'NNP'), ('.', '.'), ('Recognition', 'NN'), ('of', 'IN'), ('Indian', 'JJ'), ('Independence', 'NNP'), (',', ','), ('1947', 'CD'), ('.', '.'), ('The', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('recognized', 'VBD'), ('the', 'DT'), ('Union', 'NNP'), ('of', 'IN'), ('India', 'NNP'), ('as', 'IN'), ('an', 'DT'), ('independent', 'JJ'), ('state', 'NN'), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('when', 'WRB'), ('President', 'NNP'), ('Harry', 'NNP'), ('S.', 'NNP'), ('Truman', 'NNP'), ('sent', 'VBD'), ('a', 'DT'), ('congratulatory', 'JJ'), ('message', 'NN'), ('to', 'TO'), ('Lord', 'NNP'), ('Louis', 'NNP'), ('Mountbatten', 'NNP'), (',', ','), ('Governor', 'NNP'), ('General', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Dominion', 'NNP'), ('of', 'IN'), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('on', 'IN'), ('this', 'DT'), ('date', 'NN'), ('that', 'WDT'), (',', ','), ('in', 'IN'), ('accordance', 'NN'), ('with', 'IN'), ('the', 
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
import nltk
nltk.download('averaged_perceptron_tagger_eng')
tagged_tokens=pos_tag(tokens)
print(tagged_tokens)
# Out:
# [('U.S', 'NNP'), ('.', '.'), ('Recognition', 'NN'), ('of', 'IN'), ('Indian', 'JJ'), ('Independence', 'NNP'), (',', ','), ('1947', 'CD'), ('.', '.'), ('The', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('recognized', 'VBD'), ('the', 'DT'), ('Union', 'NNP'), ('of', 'IN'), ('India', 'NNP'), ('as', 'IN'), ('an', 'DT'), ('independent', 'JJ'), ('state', 'NN'), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('when', 'WRB'), ('President', 'NNP'), ('Harry', 'NNP'), ('S.', 'NNP'), ('Truman', 'NNP'), ('sent', 'VBD'), ('a', 'DT'), ('congratulatory', 'JJ'), ('message', 'NN'), ('to', 'TO'), ('Lord', 'NNP'), ('Louis', 'NNP'), ('Mountbatten', 'NNP'), (',', ','), ('Governor', 'NNP'), ('General', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Dominion', 'NNP'), ('of', 'IN'), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('on', 'IN'), ('this', 'DT'), ('date', 'NN'), ('that', 'WDT'), (',', ','), ('in', 'IN'), ('accordance', 'NN'), ('with', 'IN'), ('the', 
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
nltk.download('tagsets_json')
nltk.help.upenn_tagset("DT")
nltk.help.upenn_tagset("VBZ")
nltk.help.upenn_tagset("VBP")
nltk.help.upenn_tagset("VBG")
# Out:
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# [nltk_data] Downloading package tagsets_json to /root/nltk_data...
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
import nltk
nltk.download('maxent_ne_chunker_tab')
named_entities = ne_chunk(tagged_tokens)
print(named_entities)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# (S
#   (GPE U.S/NNP)
#   ./.
#   Recognition/NN
#   of/IN
#   (GPE Indian/JJ Independence/NNP)
#   ,/,
#   1947/CD
#   ./.
#   The/DT
#   (GPE United/NNP States/NNPS)
#   recognized/VBD
#   the/DT
#   (ORGANIZATION Union/NNP)
#   of/IN
#   (GPE India/NNP)
#   as/IN
#   an/DT
#   independent/JJ
#   state/NN
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   when/WRB
#   President/NNP
#   (PERSON Harry/NNP S./NNP Truman/NNP)
#   sent/VBD
#   a/DT
#   congratulatory/JJ
#   message/NN
#   to/TO
#   (PERSON Lord/NNP Louis/NNP Mountbatten/NNP)
#   ,/,
#   Governor/NNP
#   General/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Dominion/NNP)
#   of/IN
#   (GPE India/NNP)
#   ./.
#   It/PRP
#   was/VBD
#   on/IN
#   this/DT
#   date/NN
#   that/WDT
#   ,/,
#   in/IN
#   accordance/NN
#   with/IN
#   the/DT
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
from nltk.tree import Tree

# Display named entities
for subtree in named_entities:
    if isinstance(subtree, nltk.Tree):
        entity = " ".join([word for word, tag in subtree.leaves()])
        label = subtree.label()
        print(f"Entity: {entity}, Label: {label}")
# Out:
# Entity: U.S, Label: GPE
# Entity: Indian Independence, Label: GPE
# Entity: United States, Label: GPE
# Entity: Union, Label: ORGANIZATION
# Entity: India, Label: GPE
# Entity: Harry S. Truman, Label: PERSON
# Entity: Lord Louis Mountbatten, Label: PERSON
# Entity: Dominion, Label: ORGANIZATION
# Entity: India, Label: GPE
# Entity: British, Label: GPE
# Entity: Parliament, Label: ORGANIZATION
# Entity: India, Label: GPE
# Entity: Union, Label: ORGANIZATION
# Entity: India, Label: GPE
# Entity: Pakistan, Label: GPE
# Entity: British, Label: GPE
# Entity: British, Label: GPE
# Entity: Indian, Label: GPE
# Entity: British, Label: GPE
# Entity: India, Label: GPE
# Entity: India, Label: GPE
# Entity: Great Britain, Label: GPE
# Entity: India, Label: GPE
# Entity: United States, Label: GPE
# Entity: Indian, Label: GPE
# Entity: Diplomatic Relations, Label: ORGANIZATION

# %%
#Mulla Huzaifa Sufyan - 231A017
# !pip install svgling
import svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 2.9 MB/s eta 0:00:00
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
named_entities = ne_chunk(tagged_tokens)
named_entities
# Out:
# Tree('S', [Tree('GPE', [('U.S', 'NNP')]), ('.', '.'), ('Recognition', 'NN'), ('of', 'IN'), Tree('GPE', [('Indian', 'JJ'), ('Independence', 'NNP')]), (',', ','), ('1947', 'CD'), ('.', '.'), ('The', 'DT'), Tree('GPE', [('United', 'NNP'), ('States', 'NNPS')]), ('recognized', 'VBD'), ('the', 'DT'), Tree('ORGANIZATION', [('Union', 'NNP')]), ('of', 'IN'), Tree('GPE', [('India', 'NNP')]), ('as', 'IN'), ('an', 'DT'), ('independent', 'JJ'), ('state', 'NN'), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('when', 'WRB'), ('President', 'NNP'), Tree('PERSON', [('Harry', 'NNP'), ('S.', 'NNP'), ('Truman', 'NNP')]), ('sent', 'VBD'), ('a', 'DT'), ('congratulatory', 'JJ'), ('message', 'NN'), ('to', 'TO'), Tree('PERSON', [('Lord', 'NNP'), ('Louis', 'NNP'), ('Mountbatten', 'NNP')]), (',', ','), ('Governor', 'NNP'), ('General', 'NNP'), ('of', 'IN'), ('the', 'DT'), Tree('ORGANIZATION', [('Dominion', 'NNP')]), ('of', 'IN'), Tree('GPE', [('India', 'NNP')]), ('.', '.'
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
import spacy
#Load the spacy English model
nlp = spacy.load("en_core_web_sm")

#Sample text
text = "Apple is looking at buying U.K. startup for $1 billion. Bill Gates founded Microsoft."
#Process the text
doc = nlp(text)
#Extract named entities
for ent in doc.ents:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: Apple, Label: ORG
# Entity: U.K., Label: GPE
# Entity: $1 billion, Label: MONEY
# Entity: Bill Gates, Label: PERSON
# Entity: Microsoft, Label: ORG

# %%
#Part 1

# %%
# Import Required Libraries:
import nltk
from nltk import pos_tag, word_tokenize
from nltk.chunk import RegexpParser

# Sample sentence
sentence = "The quick brown fox jumps over the lazy dog."
sentence1 = "This is the class of natural language processing."

# Tokenization and POS tagging
tokens = word_tokenize(sentence1)
tagged = pos_tag(tokens)
tagged
# Out:
# [('This', 'DT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('class', 'NN'),
#  ('of', 'IN'),
#  ('natural', 'JJ'),
#  ('language', 'NN'),
#  ('processing', 'NN'),
#  ('.', '.')]

# %%
#Mulla Huzaifa Sufyan - 231A017
grammar_1 = "NP: {<DT>?<JJ>*<NN>}"

# %%
#Mulla Huzaifa Sufyan - 231A017
from nltk.chunk import RegexpParser
chunk_parser = RegexpParser(grammar_1)
chunks = chunk_parser.parse(tagged_tokens)
print(chunks)
# Out:
# (S
#   U.S/NNP
#   ./.
#   (NP Recognition/NN)
#   of/IN
#   Indian/JJ
#   Independence/NNP
#   ,/,
#   1947/CD
#   ./.
#   The/DT
#   United/NNP
#   States/NNPS
#   recognized/VBD
#   the/DT
#   Union/NNP
#   of/IN
#   India/NNP
#   as/IN
#   (NP an/DT independent/JJ state/NN)
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   when/WRB
#   President/NNP
#   Harry/NNP
#   S./NNP
#   Truman/NNP
#   sent/VBD
#   (NP a/DT congratulatory/JJ message/NN)
#   to/TO
#   Lord/NNP
#   Louis/NNP
#   Mountbatten/NNP
#   ,/,
#   Governor/NNP
#   General/NNP
#   of/IN
#   the/DT
#   Dominion/NNP
#   of/IN
#   India/NNP
#   ./.
#   It/PRP
#   was/VBD
#   on/IN
#   (NP this/DT date/NN)
#   that/WDT
#   ,/,
#   in/IN
#   (NP accordance/NN)
#   with/IN
#   the/DT
#   British/JJ
#   Parliament/NNP
#   ’/NNP
#   s/VBD
#   India/NNP
#   Independence/NNP
#   Act/NNP
#   of/IN
#   July/NNP
#   18/CD
#   ,/,
#   1947/CD
#   ,/,
#   the/DT
#   Union/NNP
#   of/IN
#   India/NNP
#   and/CC
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
from nltk.tree import tree
import svgling
svgling.draw_tree(chunks)
# Out:
# TreeLayout(Tree('S', [('U.S', 'NNP'), ('.', '.'), Tree('NP', [('Recognition', 'NN')]), ('of', 'IN'), ('Indian', 'JJ'), ('Independence', 'NNP'), (',', ','), ('1947', 'CD'), ('.', '.'), ('The', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('recognized', 'VBD'), ('the', 'DT'), ('Union', 'NNP'), ('of', 'IN'), ('India', 'NNP'), ('as', 'IN'), Tree('NP', [('an', 'DT'), ('independent', 'JJ'), ('state', 'NN')]), ('on', 'IN'), ('August', 'NNP'), ('15', 'CD'), (',', ','), ('1947', 'CD'), (',', ','), ('when', 'WRB'), ('President', 'NNP'), ('Harry', 'NNP'), ('S.', 'NNP'), ('Truman', 'NNP'), ('sent', 'VBD'), Tree('NP', [('a', 'DT'), ('congratulatory', 'JJ'), ('message', 'NN')]), ('to', 'TO'), ('Lord', 'NNP'), ('Louis', 'NNP'), ('Mountbatten', 'NNP'), (',', ','), ('Governor', 'NNP'), ('General', 'NNP'), ('of', 'IN'), ('the', 'DT'), ('Dominion', 'NNP'), ('of', 'IN'), ('India', 'NNP'), ('.', '.'), ('It', 'PRP'), ('was', 'VBD'), ('on', 'IN'), Tree('NP', [('this', 'DT'), ('date', 'NN')]), ('that', 'WD
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
grammer_2 = "NP: {<DT>?<JJ>*<NN>}"
chunk_parser = RegexpParser(grammer_2)
chunks = chunk_parser.parse(tagged_tokens)
print(chunks)
# Out:
# (S
#   U.S/NNP
#   ./.
#   (NP Recognition/NN)
#   of/IN
#   Indian/JJ
#   Independence/NNP
#   ,/,
#   1947/CD
#   ./.
#   The/DT
#   United/NNP
#   States/NNPS
#   recognized/VBD
#   the/DT
#   Union/NNP
#   of/IN
#   India/NNP
#   as/IN
#   (NP an/DT independent/JJ state/NN)
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   when/WRB
#   President/NNP
#   Harry/NNP
#   S./NNP
#   Truman/NNP
#   sent/VBD
#   (NP a/DT congratulatory/JJ message/NN)
#   to/TO
#   Lord/NNP
#   Louis/NNP
#   Mountbatten/NNP
#   ,/,
#   Governor/NNP
#   General/NNP
#   of/IN
#   the/DT
#   Dominion/NNP
#   of/IN
#   India/NNP
#   ./.
#   It/PRP
#   was/VBD
#   on/IN
#   (NP this/DT date/NN)
#   that/WDT
#   ,/,
#   in/IN
#   (NP accordance/NN)
#   with/IN
#   the/DT
#   British/JJ
#   Parliament/NNP
#   ’/NNP
#   s/VBD
#   India/NNP
#   Independence/NNP
#   Act/NNP
#   of/IN
#   July/NNP
#   18/CD
#   ,/,
#   1947/CD
#   ,/,
#   the/DT
#   Union/NNP
#   of/IN
#   India/NNP
#   and/CC
# ...

# %%
#Mulla Huzaifa Sufyan - 231A017
print(chunks)
import svgling
svgling.draw_tree(chunks)
# Out:
# (S
#   U.S/NNP
#   ./.
#   (NP Recognition/NN)
#   of/IN
#   Indian/JJ
#   Independence/NNP
#   ,/,
#   1947/CD
#   ./.
#   The/DT
#   United/NNP
#   States/NNPS
#   recognized/VBD
#   the/DT
#   Union/NNP
#   of/IN
#   India/NNP
#   as/IN
#   (NP an/DT independent/JJ state/NN)
#   on/IN
#   August/NNP
#   15/CD
#   ,/,
#   1947/CD
#   ,/,
#   when/WRB
#   President/NNP
#   Harry/NNP
#   S./NNP
#   Truman/NNP
#   sent/VBD
#   (NP a/DT congratulatory/JJ message/NN)
#   to/TO
#   Lord/NNP
#   Louis/NNP
#   Mountbatten/NNP
#   ,/,
#   Governor/NNP
#   General/NNP
#   of/IN
#   the/DT
#   Dominion/NNP
#   of/IN
#   India/NNP
#   ./.
#   It/PRP
#   was/VBD
#   on/IN
#   (NP this/DT date/NN)
#   that/WDT
#   ,/,
#   in/IN
#   (NP accordance/NN)
#   with/IN
#   the/DT
#   British/JJ
#   Parliament/NNP
#   ’/NNP
#   s/VBD
#   India/NNP
#   Independence/NNP
#   Act/NNP
#   of/IN
#   July/NNP
#   18/CD
#   ,/,
#   1947/CD
#   ,/,
#   the/DT
#   Union/NNP
#   of/IN
#   India/NNP
#   and/CC
# ...
