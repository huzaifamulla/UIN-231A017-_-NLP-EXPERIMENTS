# %% [markdown]
# <a href="https://colab.research.google.com/github/huzaifamulla/UIN-231A017-_-NLP-EXPERIMENTS/blob/main/NLP_EXP_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
text = "Keith recently came back from a trip to Chicago, Illinois. This midwestern metropolis is found along the shore of Lake Michigan."
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
#Download resources if not already done
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
import string
print(string.punctuation)
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
#Input text
# Step 1 : Preprocessing
text_lower = text.lower()
print(text_lower)
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# keith recently came back from a trip to chicago, illinois. this midwestern metropolis is found along the shore of lake michigan.

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
#Step 2: Tokenization
tokens = word_tokenize(text_lower)
print(tokens)
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# ['keith', 'recently', 'came', 'back', 'from', 'a', 'trip', 'to', 'chicago', ',', 'illinois', '.', 'this', 'midwestern', 'metropolis', 'is', 'found', 'along', 'the', 'shore', 'of', 'lake', 'michigan', '.']

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
text_clean=[]
for word in tokens:
    if word not in string.punctuation:
        text_clean.append(word)
print(text_clean)
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# ['keith', 'recently', 'came', 'back', 'from', 'a', 'trip', 'to', 'chicago', 'illinois', 'this', 'midwestern', 'metropolis', 'is', 'found', 'along', 'the', 'shore', 'of', 'lake', 'michigan']

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
#Step 3: Identify roots (morpheme approximation using lemmatizer)
lemmatizer = WordNetLemmatizer()
lemmas=[lemmatizer.lemmatize (tok, pos='v') for tok in text_clean] # Lemmatize as verbs
lemmas
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# ['keith',
#  'recently',
#  'come',
#  'back',
#  'from',
#  'a',
#  'trip',
#  'to',
#  'chicago',
#  'illinois',
#  'this',
#  'midwestern',
#  'metropolis',
#  'be',
#  'find',
#  'along',
#  'the',
#  'shore',
#  'of',
#  'lake',
#  'michigan']

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
lemmatizer.lemmatize("running", pos='n')
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# 'running'

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
[(token, lemma) for token, lemma in zip(tokens, lemmas)]
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# [('keith', 'keith'),
#  ('recently', 'recently'),
#  ('came', 'come'),
#  ('back', 'back'),
#  ('from', 'from'),
#  ('a', 'a'),
#  ('trip', 'trip'),
#  ('to', 'to'),
#  ('chicago', 'chicago'),
#  (',', 'illinois'),
#  ('illinois', 'this'),
#  ('.', 'midwestern'),
#  ('this', 'metropolis'),
#  ('midwestern', 'be'),
#  ('metropolis', 'find'),
#  ('is', 'along'),
#  ('found', 'the'),
#  ('along', 'shore'),
#  ('the', 'of'),
#  ('shore', 'lake'),
#  ('of', 'michigan')]

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
#Step 4: Analyze tokens for derivational vs inflectional
morphological_info = {}
for token_clean, lemma in zip(text_clean, lemmas):
    if token_clean != lemma:
        #This indicates some morphological change
        if token_clean.endswith("ing"):
              analysis = "Inflectional: Present participle/continuous form of '{}'".format(lemma)
        elif token_clean.endswith("er")or("ation"):
          analysis = "Derivational: '{}'+er person who does the action".format(lemma)
        else:
              analysis = "Inflectional or irregular form of '{}'".format(lemma)
    else:
              analysis = "Base/root form"
    morphological_info[token_clean]=analysis
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017

# %%
print("Name:Mulla Huzaifa Sufyan, UIN:231A017")
morphological_info
# Out:
# Name:Mulla Huzaifa Sufyan, UIN:231A017
# {'keith': 'Base/root form',
#  'recently': 'Base/root form',
#  'came': "Derivational: 'come'+er person who does the action",
#  'back': 'Base/root form',
#  'from': 'Base/root form',
#  'a': 'Base/root form',
#  'trip': 'Base/root form',
#  'to': 'Base/root form',
#  'chicago': 'Base/root form',
#  'illinois': 'Base/root form',
#  'this': 'Base/root form',
#  'midwestern': 'Base/root form',
#  'metropolis': 'Base/root form',
#  'is': "Derivational: 'be'+er person who does the action",
#  'found': "Derivational: 'find'+er person who does the action",
#  'along': 'Base/root form',
#  'the': 'Base/root form',
#  'shore': 'Base/root form',
#  'of': 'Base/root form',
#  'lake': 'Base/root form',
#  'michigan': 'Base/root form'}

# %%
#Additional Lemmitization
from nltk.corpus import wordnet

words = [
            ("playing", "v"),
            ("played", "v"),
            ("studies", "v"),
            ("running", "v"),
            ("better", "a"),
            ("cars", "n")
]

pos_map={
    'j':wordnet.ADJ,
    'v':wordnet.VERB,
    'n':wordnet.NOUN,
    'r':wordnet.ADV
}
lemmatizer = WordNetLemmatizer()
